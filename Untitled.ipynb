# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/thilinaabhisheka/Reaserach_work/Data_set.csv")

# %%
df.head()
# Out:
#                          Timestamp  \
# 0   2022/11/21 5:55:58 pm GMT+5:30
# 1   2022/11/22 9:12:07 am GMT+5:30
# 2   2022/11/22 9:13:12 am GMT+5:30
# 3   2022/11/22 9:55:56 am GMT+5:30
# 4  2022/11/22 11:16:47 am GMT+5:30
#
#   Informed Implied consent \n\nI have read and completely understood the above information    \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   I confirm that I am participating in this research voluntarily     \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                     0
# Informed Implied consent \n\nI have read and completely understood the above information      0
# I confirm that I am participating in this research voluntarily                                0
#  1.University                                                                                 0
# Batch                                                                                         0
#                                                                                              ..
#  [24.I’ve been learning to live with the pandemic.]                                           0
#  [25.I’ve been thinking hard about what steps to take about the pandemic.]                    0
#  [26.I’ve been blaming my self for the things that happened during the pandemic.]             0
#  [27.I’ve been praying or meditating due to the pandemic.]                                    0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = pd.read_csv("/Users/thilinaabhisheka/Reaserach_work/Data_set_header_cleaned.csv")

# %% [markdown]
# df1.head()

# %%
df1.isnull().duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 657     True
# 658     True
# 659     True
# 660     True
# 661     True
# Length: 662, dtype: bool
